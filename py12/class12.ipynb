# %%
print("logic1")
print("logic2")

l1: list[int] = [1, 2, 3]

try:
    print(5/2)    # error
    l1[200]
    print(xyz)
except (ZeroDivisionError, IndexError, NameError):
    print("Zero Division Error!")
print("logic4")
print("logic5")
# Out:
# logic1
# logic2
# 2.5
# Zero Division Error!
# logic4
# logic5

# %%
print("logic1")
print("logic2")

li: list[int] = [1, 2, 3]

try:
    print(5/2)    # error
    li[0]
    # print(xyz)
    open("a.txt")
except (ZeroDivisionError, IndexError, NameError):
    print("Zero Division Error!")
except IndexError:
    print("Index Error")
except NameError:
    print("Name not found")
except:
    print("Some thing went wrong")
    
print("logic4")
print("logic5")
# Out:
# logic1
# logic2
# 2.5
# Some thing went wrong
# logic4
# logic5

# %%
try:
    print(l1[200])
except Exception as e:
    print(f"Some thing went wrong\n {e}")
# Out:
# Some thing went wrong
#  list index out of range

# %%
# raise "aa"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 raise "aa"
#
# TypeError: exceptions must derive from BaseException

# %%
class studentCard():
    def __init__ (self, role_num: int, name: str, age: int) -> None:
        if age < 18 or age > 60:
            raise StudentAgeError("You are not eligible for this program!")
            
        self.role_num = role_num
        self.name = name
        self.age = age
        
class StudentAgeError(Exception):   # custom error class
    pass
        
student1 = studentCard(1, 'Usama', 25)

print(student1.age, student1.name, student1.role_num)
# Out:
# 25 Usama 1

# %%
student1 = studentCard(1, 'Usama', 17)

print(student1.age, student1.name, student1.role_num)
# Out:
# ---------------------------------------------------------------------------
# StudentAgeError                           Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 student1 = studentCard(1, 'Usama', 17)
#       3 print(student1.age, student1.name, student1.role_num)
#
# Cell In[15], line 4, in studentCard.__init__(self, role_num, name, age)
#       2 def __init__ (self, role_num: int, name: str, age: int) -> None:
#       3     if age < 18 or age > 60:
# ----> 4         raise StudentAgeError("You are not eligible for this program!")
#       6     self.role_num = role_num
#       7     self.name = name
#
# StudentAgeError: You are not eligible for this program!

# %%
student1 = studentCard(1, 'Qasim', 61)

print(student1.age, student1.name, student1.role_num)
# Out:
# ---------------------------------------------------------------------------
# StudentAgeError                           Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 student1 = studentCard(1, 'Qasim', 61)
#       3 print(student1.age, student1.name, student1.role_num)
#
# Cell In[15], line 4, in studentCard.__init__(self, role_num, name, age)
#       2 def __init__ (self, role_num: int, name: str, age: int) -> None:
#       3     if age < 18 or age > 60:
# ----> 4         raise StudentAgeError("You are not eligible for this program!")
#       6     self.role_num = role_num
#       7     self.name = name
#
# StudentAgeError: You are not eligible for this program!

# %% [markdown]
# ### File Handling
#
# https://www.geeksforgeeks.org/reading-writing-text-files-python/
#
# <img src='https://camo.githubusercontent.com/b92cb0849b0040ead2833910910cdcaa6ae32a3c6750ed36dcf02b0fd8e757a5/68747470733a2f2f6e65742d696e666f726d6174696f6e732e636f6d2f707974686f6e2f66696c652f696d672f6d6f6465732e706e67'/>

# %%
open('./abc.txt')
# Out:
# <_io.TextIOWrapper name='./abc.txt' mode='r' encoding='utf-8'>

# %%
data = open('./abc.txt')

data
# Out:
# <_io.TextIOWrapper name='./abc.txt' mode='r' encoding='utf-8'>

# %%
[i for i in dir(data) if "__" not in i]
# Out:
# ['_CHUNK_SIZE',
#  '_checkClosed',
#  '_checkReadable',
#  '_checkSeekable',
#  '_checkWritable',
#  '_finalizing',
#  'buffer',
#  'close',
#  'closed',
#  'detach',
#  'encoding',
#  'errors',
#  'fileno',
#  'flush',
#  'isatty',
#  'line_buffering',
#  'mode',
#  'name',
#  'newlines',
#  'read',
#  'readable',
#  'readline',
#  'readlines',
#  'reconfigure',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'write_through',
#  'writelines']

# %%
type(data)
# Out:
# _io.TextIOWrapper

# %%
from typing import TextIO

data: TextIO = open('./abc.txt')     # connectivity from abc.txt file

print(data.read())
# Out:
# line1
# line2

# %%
from typing import TextIO

data: TextIO = open('./abc.txt')     # connectivity from abc.txt file

print(data.read())

data.close()     # close connectivity
# Out:
# line1
# line2

# %%
with open('./abc.txt') as file: # type: TextIO
    print(type(file))
    print(file.read())
    
print("Pakistan Zindabad!")
# Out:
# <class '_io.TextIOWrapper'>
# line1
# line2
# line3
# line4
# line5
# Pakistan Zindabad!

# %%
with open('./abc.txt') as file: # type: TextIO
    print(type(file))
    print(file.readline())     # read only one line   (first line)
    print(file.readline())     # line 2
    
print("Pakistan Zindabad!")
# Out:
# <class '_io.TextIOWrapper'>
# line1
#
# line2
#
# Pakistan Zindabad!

# %%
with open('./abc.txt') as file: # type: TextIO
    print(type(file))
    print(file.readline(), end="")     # read only one line   (first line)
    print(file.readline(), end="")     # line 2
    
print("Pakistan Zindabad!")
# Out:
# <class '_io.TextIOWrapper'>
# line1
# line2
# Pakistan Zindabad!

# %%
with open('./abc.txt') as file: # type: TextIO
    print(type(file))
    print(file.readlines())   #
# Out:
# <class '_io.TextIOWrapper'>
# ['line1\n', 'line2\n', 'line3\n', 'line4\n', 'line5']

# %%
with open('./abc.txt', 'r') as file: # type: TextIO
    print(type(file))
    print(file.readlines()[:3])   #
# Out:
# <class '_io.TextIOWrapper'>
# ['line1\n', 'line2\n', 'line3\n']

# %%
with open('./abc.txt', 'r') as file: # type: TextIO
    print(file.read())
    file.write("Pakistan zindabad")
# Out:
# line1
# line2
# line3
# line4
# line5
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[40], line 3
#       1 with open('./abc.txt', 'r') as file: # type: TextIO
#       2     print(file.read())
# ----> 3     file.write("Pakistan zindabad")
#
# UnsupportedOperation: not writable

# %%
with open('./abc.txt', 'w') as file: # type: TextIO
    print(file.read())
    file.write("Pakistan zindabad")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[41], line 2
#       1 with open('./abc.txt', 'w') as file: # type: TextIO
# ----> 2     print(file.read())
#       3     file.write("Pakistan zindabad")
#
# UnsupportedOperation: not readable

# %%
with open('./abc1.txt', 'w') as file: # type: TextIO
    file.write("Pakistan zindabad")

# %%
with open('./abc1.txt', 'r+') as file: # type: TextIO
    print(file.read())
    file.write("WE love our country")
# Out:
# Pakistan zindabad

# %%
with open('./abc1.txt', 'r+') as file: # type: TextIO
    print(file.read())
    
    file.write("WE love our country")
    
    print("After", file.read())
# Out:
# Pakistan zindabad
# After

# %%
with open('./abc1.txt', 'r+') as file: # type: TextIO
    print(file.read())
    
    file.write("WE love our country")
    file.seek(0)
    
    print("After", file.read())
# Out:
# Pakistan zindabad
# After Pakistan zindabadWE love our country

# %% [markdown]
# ### Now change modes

# %%
with open('./abc2.txt', 'r') as file: # type: TextIO
    print(file.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 with open('./abc2.txt', 'r') as file: # type: TextIO
#       2     print(file.read())
#
# File c:\Users\Netever\anaconda3\envs\python12\Lib\site-packages\IPython\core\interactiveshell.py:325, in _modified_open(file, *args, **kwargs)
#     318 if file in {0, 1, 2}:
#     319     raise ValueError(
#     320         f"IPython won't let you open fd={file} by default "
#     321         "as it is likely to crash IPython. If you know what you are doing, "
#     322         "you can use builtins' open."
#     323     )
# --> 325 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './abc2.txt'

# %%
with open('./abc2.txt', 'w') as file: # type: TextIO
    # print(file.read())
    file.write("Pakistan")
    
# if file exist then will overwrite the text
# if file not exist then it will create new file

# %%
with open('./abc3.txt', 'a') as file: # type: TextIO
    # print(file.read())
    file.write("Pakistan")
    
# if file exist then will overwrite the text
# if file not exist then it will create new file

# %%
with open('./abc3.txt', 'a') as file: # type: TextIO
    # print(file.read())
    file.write("line3")
    
# if file exist then will overwrite the text
# add content in last

# %%
with open('./abc4.txt', 'x') as file: # type: TextIO
    # print(file.read())
    file.write("line3")
    
# if file exist then will overwrite the text
# if file not exist then it will create new file

# %%
with open('./abc4.txt', 'x') as file: # type: TextIO
    # print(file.read())
    file.write("line3")
    
# if file exist then will overwrite the text
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 with open('./abc4.txt', 'x') as file: # type: TextIO
#       2     # print(file.read())
#       3     file.write("line3")
#       5 # if file exist then will overwrite the text
#
# File c:\Users\Netever\anaconda3\envs\python12\Lib\site-packages\IPython\core\interactiveshell.py:325, in _modified_open(file, *args, **kwargs)
#     318 if file in {0, 1, 2}:
#     319     raise ValueError(
#     320         f"IPython won't let you open fd={file} by default "
#     321         "as it is likely to crash IPython. If you know what you are doing, "
#     322         "you can use builtins' open."
#     323     )
# --> 325 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: './abc4.txt'

# %%
with open('./abc4.txt', 'rb+') as file: # type: TextIO
    print(file.read())
    # file.write("line3")
    
# if file exist then will overwrite the text
# Out:
# b'line3'

# %% [markdown]
# <table class=\"s-table\">
#         <thead>
#         <tr>
#         <th style=\"text-align: center;\">Mode</th>
#         <th style=\"text-align: center;\">r</th>
#         <th style=\"text-align: center;\">r+</th>
#         <th style=\"text-align: center;\">w</th>
#         <th style=\"text-align: center;\">w+</th>
#         <th style=\"text-align: center;\">a</th>
#         <th style=\"text-align: center;\">a+</th>
#         </tr>
#         </thead>
#         <tbody>
#         <tr>
#         <td style=\"text-align: center;\">Read</td>
#         <td style=\"text-align: center;\">+</td>
#         <td style=\"text-align: center;\">+</td>
#         <td style=\"text-align: center;\"></td>
#         <td style=\"text-align: center;\">+</td>
#         <td style=\"text-align: center;\"></td>
#         <td style=\"text-align: center;\">+</td>
#         </tr>
#         <tr>
#         <td style=\"text-align: center;\">Write</td>
#         <td style=\"text-align: center;\"></td>
#         <td style=\"text-align: center;\">+</td>
#         <td style=\"text-align: center;\">+</td>
#         <td style=\"text-align: center;\">+</td>
#         <td style=\"text-align: center;\">+</td>
#         <td style=\"text-align: center;\">+</td>
#         </tr>
#     <tr>
#         <td style=\"text-align: center;\">Create</td>
#         <td style=\"text-align: center;\"></td>
#         <td style=\"text-align: center;\"></td>
#         <td style=\"text-align: center;\">+</td>
#         <td style=\"text-align: center;\">+</td>
#         <td style=\"text-align: center;\">+</td>
#         <td style=\"text-align: center;\">+</td>
#         </tr>
#         <tr>
#         <td style=\"text-align: center;\">Cover</td>
#         <td style=\"text-align: center;\"></td>
#         <td style=\"text-align: center;\"></td>
#         <td style=\"text-align: center;\">+</td>
#         <td style=\"text-align: center;\">+</td>
#         <td style=\"text-align: center;\"></td>
#         <td style=\"text-align: center;\"></td>
#         </tr>
#         <tr>
#         <td style=\"text-align: center;\">Point in the beginning</td>
#         <td style=\"text-align: center;\">+</td>
#         <td style=\"text-align: center;\">+</td>
#         <td style=\"text-align: center;\">+</td>
#         <td style=\"text-align: center;\">+</td>
#         <td style=\"text-align: center;\"></td>
#         <td style=\"text-align: center;\"></td>
#         </tr>
#         <tr>
#         <td style=\"text-align: center;\">Point in the end</td>
#         <td style=\"text-align: center;\"></td>
#         <td style=\"text-align: center;\"></td>
#         <td style=\"text-align: center;\"></td>
#         <td style=\"text-align: center;\"></td>
#         <td style=\"text-align: center;\">+</td>
#         <td style=\"text-align: center;\">+</td>
#         </tr>
#         </tbody>
#         </table>

# %% [markdown]
# ### Read some real world data files
#
# - image
# - csv
# - live cemera

# %%
import pandas as pd

df: pd.DataFrame = pd.read_csv('./data.csv')

df
# Out:
#    id   name education
# 0   1  Usama      BSSE
# 1   2  Qasim       MSC
# 2   3    Ali      BSCS

# %%
import pandas as pd

df: pd.DataFrame = pd.read_excel('./demo.xlsx')

df
# Out:
#    1    Usama    BSSE
# 0  2    Qasim  Master
# 1  3      Ali    BSCS
# 2  4  Sir Zia     PHD

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread("./img1.jpeg")    # convert into numpy array

plt.imshow(img)

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.3-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.58.2-cp312-cp312-win_amd64.whl.metadata (108 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\netever\anaconda3\envs\python12\lib\site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\netever\anaconda3\envs\python12\lib\site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.2.1-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\netever\anaconda3\envs\python12\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\netever\anaconda3\envs\python12\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.3-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 699.0 kB/s eta 0:00:11
#    --- ------------------------------------ 0.8/8.1 MB 884.1 kB/s eta 0:00:09
#    --- ------------------------------------ 0.8/8.1 MB 884.1 kB/s eta 0:00:09
#    ----- ---------------------------------- 1.0/8.1 MB 853.0 kB/s eta 0:00:09
#    ------ --------------------------------- 1.3/8.1 MB 838.9 kB/s eta 0:00:09
#    ------ --------------------------------- 1.3/8.1 MB 838.9 kB/s eta 0:00:09
#    ------- -------------------------------- 1.6/8.1 MB 839.1 kB/s eta 0:00:08
#    --------- ------------------------------ 1.8/8.1 MB 838.9 kB/s eta 0:00:08
#    --------- ------------------------------ 1.8/8.1 MB 838.9 kB/s eta 0:00:08
#    ---------- ----------------------------- 2.1/8.1 MB 844.8 kB/s eta 0:00:08
#    ----------- ---------------------------- 2.4/8.1 MB 871.6 kB/s eta 0:00:07
#    ------------ --------------------------- 2.6/8.1 MB 862.9 kB/s eta 0:00:07
#    ------------ --------------------------- 2.6/8.1 MB 862.9 kB/s eta 0:00:07
#    -------------- ------------------------- 2.9/8.1 MB 847.5 kB/s eta 0:00:07
#    --------------- ------------------------ 3.1/8.1 MB 870.6 kB/s eta 0:00:06
#    ---------------- ----------------------- 3.4/8.1 MB 860.4 kB/s eta 0:00:06
#    ------------------ --------------------- 3.7/8.1 MB 879.5 kB/s eta 0:00:06
#    ------------------ --------------------- 3.7/8.1 MB 879.5 kB/s eta 0:00:06
#    ------------------- -------------------- 3.9/8.1 MB 873.2 kB/s eta 0:00:05
#    ------------------- -------------------- 3.9/8.1 MB 873.2 kB/s eta 0:00:05
#    ---------------------- ----------------- 4.5/8.1 MB 883.0 kB/s eta 0:00:05
#    ---------------------- ----------------- 4.5/8.1 MB 883.0 kB/s eta 0:00:05
#    ----------------------- ---------------- 4.7/8.1 MB 880.4 kB/s eta 0:00:04
#    ------------------------ --------------- 5.0/8.1 MB 893.5 kB/s eta 0:00:04
#    ------------------------- -------------- 5.2/8.1 MB 888.0 kB/s eta 0:00:04
#    ------------------------- -------------- 5.2/8.1 MB 888.0 kB/s eta 0:00:04
#    --------------------------- ------------ 5.5/8.1 MB 897.3 kB/s eta 0:00:03
#    ---------------------------- ----------- 5.8/8.1 MB 896.6 kB/s eta 0:00:03
#    ----------------------------- ---------- 6.0/8.1 MB 906.9 kB/s eta 0:00:03
#    ------------------------------- -------- 6.3/8.1 MB 901.6 kB/s eta 0:00:02
#    ------------------------------- -------- 6.3/8.1 MB 901.6 kB/s eta 0:00:02
#    -------------------------------- ------- 6.6/8.1 MB 908.9 kB/s eta 0:00:02
#    --------------------------------- ------ 6.8/8.1 MB 905.9 kB/s eta 0:00:02
#    ----------------------------------- ---- 7.1/8.1 MB 914.5 kB/s eta 0:00:02
#    ------------------------------------ --- 7.3/8.1 MB 922.6 kB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 922.6 kB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 919.3 kB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 926.8 kB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 911.7 kB/s eta 0:00:00
# Downloading contourpy-1.3.2-cp312-cp312-win_amd64.whl (223 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.58.2-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 1.2 MB/s eta 0:00:02
#    --------- ------------------------------ 0.5/2.2 MB 1.2 MB/s eta 0:00:02
#    -------------- ------------------------- 0.8/2.2 MB 780.2 kB/s eta 0:00:02
#    ------------------ --------------------- 1.0/2.2 MB 786.4 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.3/2.2 MB 860.2 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.3/2.2 MB 860.2 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.6/2.2 MB 855.6 kB/s eta 0:00:01
#    -------------------------------- ------- 1.8/2.2 MB 890.6 kB/s eta 0:00:01
#    ------------------------------------- -- 2.1/2.2 MB 876.3 kB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 885.3 kB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Downloading pillow-11.2.1-cp312-cp312-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 1.2 MB/s eta 0:00:02
#    ------- -------------------------------- 0.5/2.7 MB 1.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.8/2.7 MB 763.2 kB/s eta 0:00:03
#    --------------- ------------------------ 1.0/2.7 MB 868.0 kB/s eta 0:00:02
#    ------------------- -------------------- 1.3/2.7 MB 860.9 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.6/2.7 MB 912.1 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.6/2.7 MB 912.1 kB/s eta 0:00:02
#    --------------------------- ------------ 1.8/2.7 MB 891.1 kB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.7 MB 883.1 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.7 MB 913.0 kB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.7 MB 913.0 kB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 898.6 kB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.58.2 kiwisolver-1.4.8 matplotlib-3.10.3 pillow-11.2.1 pyparsing-3.2.3

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
from typing import List
import PyPDF2

def read_pdf(file_path: str) -> List[str]:
    with open(file_path, 'rb') as file:  # The 'b' in 'rb' stands for binary mode
        reader: PyPDF2.PdfReader = PyPDF2.PdfReader(file)
        text_content: List[str] = [page.extract_text() for page in reader.pages]
        return text_content

pages: list[str] = read_pdf("./mypdf.pdf")
pages
# Out:
# ['Pakistan\n \nzindabad\n ', 'We\n \nlove\n \nour\n \ncountry\n ', 'PIAIC\n ']
